# %%
import pandas as pd
import numpy as np
from binarization_utils import convert_continuous_df_to_binary_df

# %% [markdown]
# # Read Sample dataset

# %%
df = pd.read_csv("spambase_continuous.csv")
df
# Out:
#        y_label  word_freq_make   word_freq_address   word_freq_all  \
# 0            1            0.00                0.64            0.64
# 1            1            0.21                0.28            0.50
# 2            1            0.06                0.00            0.71
# 3            1            0.00                0.00            0.00
# 4            1            0.00                0.00            0.00
# ...        ...             ...                 ...             ...
# 4596         0            0.31                0.00            0.62
# 4597         0            0.00                0.00            0.00
# 4598         0            0.30                0.00            0.30
# 4599         0            0.96                0.00            0.00
# 4600         0            0.00                0.00            0.65
#
#        word_freq_3d   word_freq_our   word_freq_over   word_freq_remove  \
# 0               0.0            0.32             0.00               0.00
# ...

# %% [markdown]
# # Convert continuous dataframe to binary dataframe

# %%
df_binarized = convert_continuous_df_to_binary_df(df)
df_binarized
# Out:
# Make sure your first column corresponds to the y label
# Converting continuous features to binary features in the dataframe......
# Finish converting continuous features to binary features......
#        y_label  word_freq_make<=0.0141  word_freq_make<=0.028199999999999996  \
# 0            1                       1                                     1
# 1            1                       0                                     0
# 2            1                       0                                     0
# 3            1                       1                                     1
# 4            1                       1                                     1
# ...        ...                     ...                                   ...
# 4596         0                       0                                     0
# 4597         0                       1                                     1
# 4598         0                       0                                     0
# ...

# %% [markdown]
# # Save new binary dataframe to a csv file

# %%
df_binarized.to_csv("spambase_binary.csv")
